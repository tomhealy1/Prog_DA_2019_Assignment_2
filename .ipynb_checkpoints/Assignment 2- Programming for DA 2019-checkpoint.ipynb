# %% [markdown]
# ![title](images/gmit.PNG)

# %% [markdown]
# ## GMIT HDip Data Analytics 2019
# ## Fundamentals of Data Analysis - Semester 2 - Assignment 1
# ## Thomas Healy G00376351

# %% [markdown]
# ![title](images/numpya.PNG)

# %% [markdown]
# ## Table of contents
#
# #### 1. Description of the assignment and selection of real world phenomenon
# #### 2. Investigation of phenonmenon's variables
# #### 3. Synthesis a dataset
# #### 4. Detail research and implement the simulation

# %% [markdown]
# # 1. Description of assignment and selection of real world phenomenon
#
# The assignment is re-create a real world phenonmenon using the ```numpy.random``` package to model the distributions in the phenomenon I have chosen. The phenonmenon I have chosen is that of HR data. The IBM dataset is a popular dataset that IBM developed to allow machine learning be ran on realtively large ( 1470 rows with 35 columns). It is a contrived datset as there are serious privacy and ethical issues surrounding the use of HR data in data science. I have selected this phenomenon as working in HR it can be difficult to find datasets that are relevant and can vbe used for HR or people Analytics purposes. I propose to take a few columns below and plot their distribution and then change some of them.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('IBMHRdata_set.csv')

# %%
print(df)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...

# %%
x = sns.countplot(df['RelationshipSatisfaction'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-3d28f678b245> in <module>
#       1 x = sns.countplot(df['RelationshipSatisfaction'])
# ----> 2 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# ...

# %% [markdown]
# # 2. Selection of Real World phenomenon

# %% [markdown]
# # 3. Investigation of phenonmenon's variables

# %% [markdown]
# # 4. Synthesis a dataset

# %% [markdown]
# # 5. Detail research and implement the simulation
